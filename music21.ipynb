# %% [markdown]
# # Learn music21

# %%
from music21 import *

# %%
s = corpus.parse('bach/bwv65.2.xml')

# %%
voice = s.parts[0]
voice.measures(0, 8).plot()
# Out:
# <music21.graph.plot.HorizontalBarPitchSpaceOffset for <music21.stream.Part Soprano>>

# %%
voice.measures(0, 8).show()

# %%
s
# Out:
# <music21.stream.Score 0x7f9a065065b0>

# %%
s.analyze('key')
# Out:
# <music21.key.Key of a minor>

# %%
s.show()

# %%
test_music = converter.parse("./classical-music-midi/chopin/chp_op18.mid")
# Out:
# /Users/yilinli/opt/anaconda3/lib/python3.8/site-packages/music21/midi/translate.py:883: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, channel=None, data=b'Copyright \xa9 1997 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(

# %%
test_music.analyze('key')
# Out:
# <music21.key.Key of A- major>

# %%
test_music[0].show()

# %%
test_music.show()

# %%
chopin_stream = instrument.partitionByInstrument(test_music[0])

# %%
chopin_stream.parts[0]
# Out:
# <music21.stream.Part Piano right>

# %%
pick_test = chopin_stream.parts[0].recurse()

# %%
pick_test
# Out:
# <music21.stream.iterator.RecursiveIterator for Part:Piano right @:0>

# %%
for element in pick_test:
    if isinstance(element, note.Note):
        print(str(element.pitch))
    elif isinstance(element, chord.Chord):
        notes.append(".".join(str(n) for n in element.normalOrder))

# %%
notes = []
pick = None
for j in test_music:
    songs = instrument.partitionByInstrument(j)
    for part in songs.parts:
        pick = part.recurse()
        for element in pick:
            if isinstance(element, note.Note):
                notes.append(str(element.pitch.midi))
            elif isinstance(element, chord.Chord):
                notes.append(".".join(str(n) for n in element.normalOrder))

# %%
notes[18]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f756049b87af> in <module>
# ----> 1 notes[18]
#
# NameError: name 'notes' is not defined

# %% [markdown]
# # Chapter 2 Notes

# %%
note
# Out:
# <module 'music21.note' from '/Users/yilinli/opt/anaconda3/lib/python3.8/site-packages/music21/note.py'>

# %%
dir(note)
# Out:
# ['GeneralNote',
#  'Lyric',
#  'LyricException',
#  'NotRest',
#  'NotRestException',
#  'Note',
#  'NoteException',
#  'Rest',
#  'SYLLABIC_CHOICES',
#  'Unpitched',
#  'base',
#  'beam',
#  'common',
#  'duration',
#  'environLocal',
#  'environment',
#  'exceptions21',
#  'expressions',
#  'interval',
#  'noteheadTypeNames',
#  'pitch',
#  'prebase',
#  'stemDirectionNames',
#  'style',
#  'tie',
#  'volume']

# %%
f = note.Note("F5")

# %%
f.pitch.pitchClass
# Out:
# 5

# %%
bflat = note.Note("B-2")

# %%
bflat.pitch.accidental
# Out:
# <music21.pitch.Accidental flat>

# %%
f.pitch.accidental is None
# Out:
# True

# %%
acc = bflat.pitch.accidental
acc
# Out:
# <music21.pitch.Accidental flat>

# %%
bflat.pitch.accidental.alter
# Out:
# -1.0

# %%
f.show()

# %%
f.show('midi')
# Out:
#                 <div id='midiPlayerDiv985244'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv985244');
#                                mp.base64Load('...');
#                         });
#                 </script>

# %%
import IPython
from IPython.display import Image, Audio

# %%
d = bflat.transpose("M3")
d
# Out:
# <music21.note.Note D>

# %%
bflat
# Out:
# <music21.note.Note B->

# %%
r = note.Rest()

# %% [markdown]
# # Chapter 3: Pitches, Durations, and Notes again

# %%
p1 = pitch.Pitch('b-4')

# %%
p1.octave
# Out:
# 4

# %%
p1.pitchClass
# Out:
# 10

# %%
p1.midi
# Out:
# 70

# %%
pitch.Pitch('C#4').midi
# Out:
# 61

# %%
p2 = pitch.Pitch('6.10.1')
# Out:
# ---------------------------------------------------------------------------
# PitchException                            Traceback (most recent call last)
# <ipython-input-32-0b4bf85c07b4> in <module>
# ----> 1 p2 = pitch.Pitch('6.10.1')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/music21/pitch.py in __init__(self, name, **keywords)
#    1794         if name is not None:
#    1795             if isinstance(name, str):
# -> 1796                 self.name = name  # set based on string
#    1797             else:  # is a number
#    1798                 if name < 12:  # is a pitchClass
#
# ~/opt/anaconda3/lib/python3.8/site-packages/music21/pitch.py in name(self, usrStr)
#    2621         # assume everything following pitch is accidental specification
#    2622         elif len(usrStr) > 1:
# -> 2623             self.step = usrStr[0]
#    2624             self.accidental = Accidental(usrStr[1:])
#    2625         else:
#
# ...

# %%
c1 = chord.Chord('6.10.1')
# Out:
# ---------------------------------------------------------------------------
# PitchException                            Traceback (most recent call last)
# <ipython-input-45-c6efcc53b214> in <module>
# ----> 1 c1 = chord.Chord('6.10.1')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/music21/chord/__init__.py in __init__(self, notes, **keywords)
#     673         if notes is not None and any(isinstance(n, note.Unpitched) for n in notes):
#     674             raise TypeError(f'Use a PercussionChord to contain Unpitched objects; got {notes}')
# --> 675         super().__init__(notes=notes, **keywords)
#     676
#     677         if notes is not None and all(isinstance(n, int) for n in notes):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/music21/chord/__init__.py in __init__(self, notes, **keywords)
#     112             durationKeyword = keywords['duration']
#     113
# --> 114         durationKeyword = self._add_core_or_init(notes, useDuration=durationKeyword)
#     115
# ...
